# %%
import numpy as np
import matplotlib.pyplot as plt 
from scipy.interpolate import splrep,splint,splev,BSpline,sproot,splprep,bisplrep,bisplev
from matplotlib import rcParams
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import RectBivariateSpline
# %matplotlib inline

# %%
x=np.array([284.3176636,
366.3113561,
446.2501868,
532.9362936,
610.6267038,
686.560919,
782.9284561,
875.2333749,
956.9200943,
1037.618905,
1125.18537,
1204.26108,
1292.665406,
1369.04215,
1440.69332,
1513.283377,
1585.042439,
1647.130346,
1717.120679,
1782.830777])
y=np.array([0.029775329,
0.139752835,
0.249797077,
0.372510584,
0.485620663,
0.599241343,
0.748274308,
0.896347376,
1.032144781,
1.170911557,
1.327336227,
1.474017178,
1.644612963,
1.798186847,
1.947681362,
2.104947183,
2.266370509,
2.411407252,
2.581179947,
2.746424112])

# %%
#########################################
# Solución 1.1
#########################################
h=lambda x,C,K,A,B: C*((x**4)-A)+K*(x-B)
popth,pcovh=cfit(h,x,y)
C,K,A,B=popth
yh=h(x,C,K,A,B)
#######################################
# Gráfica de la función
#######################################
plt.figure(figsize=(10,10/1.618),dpi=100)
plt.scatter(x,y,s=25,color=(0.6,0.6,0.3,0.7),marker='X')
plt.plot(x,yh)
plt.legend(['Ajuste polinomial','Datos'])
plt.title('Potencia contra Temperatura')
plt.xlabel('T (K)')
plt.ylabel('P (W)')
plt.legend(['Ajuste polinomial','Datos'])
plt.style.use('seaborn-whitegrid')
plt.show()


print(C,K,A,B)
# Out:
# C:\Users\AQ01097\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 5.56877039097842e-14 0.0014592786502874576 1.0 276.982268571464

# %%
f=plt.figure(figsize=(14,7))
chis=sum((y-yh)**2)/(19)
ax2 = f.add_subplot(122,title="Residuales grado 4. $\chi_v^2 ={0:0.3f}$ .".format(chis))
ax2.scatter(x,y-yh,s=50,marker="h",color=(0.1,0.8,0.2,0.8))

# %%
#########################################
# Solución 1.2
#########################################
h=lambda x,C,K,A,B,D: C*((x**A)-(D**A))+K*((x-D)**B)
popth,pcovh=cfit(h,x,y)
C,K,A,B,D=popth
yh=h(x,C,K,A,B,D)
#######################################
# Gráfica de la función
#######################################
plt.figure(figsize=(10,10/1.618),dpi=100)
plt.scatter(x,y,s=25,color=(0.6,0.6,0.3,0.7),marker='X')
plt.plot(x,yh)
plt.legend(['Ajuste polinomial','Datos'])
plt.title('Potencia contra Temperatura')
plt.xlabel('T (K)')
plt.ylabel('P (W)')
plt.legend(['Ajuste polinomial','Datos'])
plt.style.use('seaborn-whitegrid')
plt.show()


print(C,K,A,B,D)
# Out:
# <ipython-input-5-e36f293a2b48>:4: RuntimeWarning: invalid value encountered in double_scalars
#   h=lambda x,C,K,A,B,D: C*((x**A)-(D**A))+K*((x-D)**B)
# 0.025274359932754096 -0.036007257235519056 0.911629259457606 0.8480005970873274 1.2555376430778181e-06

# %%
x=np.array([284.3176636,
453.9699093,
629.799814,
797.6769548,
957.6015243,
1119.567055,
1271.42239,
1410.616012,
1560.492515,
1706.246663,
1853.857976,
1997.796574,
2135.299987,
2264.8515,
2398.509941,
2525.599429,
2653.285458,
2792.446546,
2926.291077,
3060.887138])
y=np.array([0.029761339,
0.260730877,
0.514337481,
0.771758185,
1.032424489,
1.317288194,
1.603638101,
1.884705032,
2.210397076,
2.552879844,
2.93123636,
3.334763841,
3.754868142,
4.183226964,
4.66561378,
5.164557738,
5.712896552,
6.369730908,
7.065828291,
7.82710549])
#########################################
# Solución 1.1
#########################################
#########################################
# Solución 1.1
#########################################
h=lambda x,C,K,A,B: C*((x**4)-A)+K*(x-B)
popth,pcovh=cfit(h,x,y)
C,K,A,B=popth
yh=h(x,C,K,A,B)
#######################################
# Gráfica de la función
#######################################
plt.figure(figsize=(10,10/1.618),dpi=100)
plt.scatter(x,y,s=25,color=(0.6,0.6,0.3,0.7),marker='X')
plt.plot(x,yh)
plt.legend(['Ajuste polinomial','Datos'])
plt.title('Potencia contra Temperatura')
plt.xlabel('T (K)')
plt.ylabel('P (W)')
plt.legend(['Ajuste polinomial','Datos'])
plt.style.use('seaborn-whitegrid')
plt.show()


print(C,K,A,B)
# Out:
# C:\Users\AQ01097\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 3.972437602430307e-14 0.0015891759553195927 1.0 307.01330169080563

# %%
f=plt.figure(figsize=(14,7))
chis=sum((y-yh)**2)/(19)
ax2 = f.add_subplot(122,title="Residuales ajuste polinomial grado 4. $\chi_v^2 ={0:0.3f}$ .".format(chis))
ax2.scatter(x,y-yh,s=50,marker="h",color=(0.1,0.8,0.2,0.8))

# %%
#########################################
# Solución 1.2
#########################################
h=lambda x,C,K,A,B: C*((x**A)-(284.3176636**A))+K*((x-284.3176636)**B)
popth,pcovh=cfit(h,x,y)
C,K,A,B=popth
yh=h(x,C,K,A,B)
#######################################
# Gráfica de la función
#######################################
plt.figure(figsize=(10,10/1.618),dpi=100)
plt.scatter(x,y,s=25,color=(0.6,0.6,0.3,0.7),marker='X')
plt.plot(x,yh)
plt.legend(['Ajuste polinomial','Datos'])
plt.title('Potencia contra Temperatura')
plt.xlabel('T (K)')
plt.ylabel('P (W)')
plt.legend(['Ajuste polinomial','Datos'])
plt.style.use('seaborn-whitegrid')
plt.show()


print(C,K,A,B,D)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-b93ec61c6202> in <module>
#       3 #########################################
#       4 h=lambda x,C,K,A,B: C*((x**A)-(284.3176636**A))+K*((x-284.3176636)**B)
# ----> 5 popth,pcovh=cfit(h,x,y)
#       6 C,K,A,B=popth
#       7 yh=h(x,C,K,A,B)
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     787         cost = np.sum(infodict['fvec'] ** 2)
#     788         if ier not in [1, 2, 3, 4]:
# --> 789             raise RuntimeError("Optimal parameters not found: " + errmsg)
#     790     else:
#     791         # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 1000.

# %%
x=np.array([284.3176636,
551.6835143,
798.962437,
1039.561016,
1273.088771,
1500.196084,
1720.195199,
1938.600895,
2142.05813,
2342.807289,
2549.275348,
2742.756648,
2939.134239,
3124.565103,
3305.807961,
3486.372532,
3650.741479,
3810.489663,
3968.996277,
4114.110483])
y=np.array([0.029765059,
0.39923197,
0.774170677,
1.174194178,
1.605984797,
2.07579675,
2.588021207,
3.167298365,
3.773726881,
4.459255404,
5.266626361,
6.130864476,
7.130262202,
8.228097139,
9.447957326,
10.86259603,
12.33989562,
14.03314459,
15.99901292,
18.1431766])
#########################################
# Solución 1.1
#########################################
h=lambda x,C,K,A,B: C*((x**4)-A)+K*(x-B)
popth,pcovh=cfit(h,x,y)
C,K,A,B=popth
yh=h(x,C,K,A,B)
#######################################
# Gráfica de la función
#######################################
plt.figure(figsize=(10,10/1.618),dpi=100)
plt.scatter(x,y,s=25,color=(0.6,0.6,0.3,0.7),marker='X')
plt.plot(x,yh)
plt.legend(['Ajuste polinomial','Datos'])
plt.title('Potencia contra Temperatura')
plt.xlabel('T (K)')
plt.ylabel('P (W)')
plt.legend(['Ajuste polinomial','Datos'])
plt.style.use('seaborn-whitegrid')
plt.show()


print(C,K,A,B)
# Out:
# C:\Users\AQ01097\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 4.2371964667731755e-14 0.001472381012462726 1.0 249.51302242999307

# %%
f=plt.figure(figsize=(14,7))
chis=sum((y-yh)**2)/(19)
ax2 = f.add_subplot(122,title="Residuales ajuste polinomial grado 4. $\chi_v^2 ={0:0.3f}$ .".format(chis))
ax2.scatter(x,y-yh,s=50,marker="h",color=(0.1,0.8,0.2,0.8))

# %%
#########################################
# Solución 1.2
#########################################
h=lambda x,C,K,A,B,D: C*((x**A)-(D**A))+K*((x-D)**B)
popth,pcovh=cfit(h,x,y)
C,K,A,B,D=popth
yh=h(x,C,K,A,B,D)
#######################################
# Gráfica de la función
#######################################
plt.figure(figsize=(10,10/1.618),dpi=100)
plt.scatter(x,y,s=25,color=(0.6,0.6,0.3,0.7),marker='X')
plt.plot(x,yh)
plt.legend(['Ajuste polinomial','Datos'])
plt.title('Potencia contra Temperatura')
plt.xlabel('T (K)')
plt.ylabel('P (W)')
plt.legend(['Ajuste polinomial','Datos'])
plt.style.use('seaborn-whitegrid')
plt.show()


print(C,K,A,B,D)
# Out:
# <ipython-input-13-e36f293a2b48>:4: RuntimeWarning: invalid value encountered in double_scalars
#   h=lambda x,C,K,A,B,D: C*((x**A)-(D**A))+K*((x-D)**B)
# <ipython-input-13-e36f293a2b48>:4: RuntimeWarning: invalid value encountered in power
#   h=lambda x,C,K,A,B,D: C*((x**A)-(D**A))+K*((x-D)**B)
# 0.09255229602953653 -0.1144879337995267 1.0164170506374248 0.9863747131120599 284.3172438209245

# %%
x=np.array([284.3176636,
642.9781792,
969.7171271,
1272.629993,
1563.578152,
1859.942516,
2142.596092,
2412.6414,
2679.910451,
2936.762225,
3181.825464,
3425.582522,
3657.027769,
3878.425742,
4079.053961,
4263.490801,
4418.865128,
4539.318755,
4624.21172,
4664.448852])
y=np.array([0.029805601,
0.53330141,
1.054361548,
1.602831531,
2.218403076,
2.950316802,
3.776471872,
4.719037431,
5.820382305,
7.131223726,
8.583141587,
10.36016182,
12.42541544,
14.82400409,
17.58731903,
20.89835724,
24.54251073,
28.70507858,
33.56775713,
39.09436578])
#########################################
# Solución 1.1
#########################################
h=lambda x,C,K,A,B: C*((x**4)-A)+K*(x-B)
popth,pcovh=cfit(h,x,y)
C,K,A,B=popth
yh=h(x,C,K,A,B)
#######################################
# Gráfica de la función
#######################################
plt.figure(figsize=(10,10/1.618),dpi=100)
plt.scatter(x,y,s=25,color=(0.6,0.6,0.3,0.7),marker='X')
plt.plot(x,yh)
plt.legend(['Ajuste polinomial','Datos'])
plt.title('Potencia contra Temperatura')
plt.xlabel('T (K)')
plt.ylabel('P (W)')
plt.legend(['Ajuste polinomial','Datos'])
plt.style.use('seaborn-whitegrid')
plt.show()


print(C,K,A,B)
# Out:
# C:\Users\AQ01097\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 6.867846438277406e-14 -0.00012140088611461876 1.0 11618.224775974435

# %%
f=plt.figure(figsize=(14,7))
chis=sum((y-yh)**2)/(19)
ax2 = f.add_subplot(122,title="Residuales ajuste polinomial grado 4. $\chi_v^2 ={0:0.3f}$ .".format(chis))
ax2.scatter(x,y-yh,s=50,marker="h",color=(0.1,0.8,0.2,0.8))

# %%
#########################################
# Solución 1.2
#########################################
h=lambda x,C,K,A,B: C*((x**A)-(284.3176636**A))+K*((x-284.3176636)**B)
popth,pcovh=cfit(h,x,y)
C,K,A,B=popth
yh=h(x,C,K,A,B)
#######################################
# Gráfica de la función
#######################################
plt.figure(figsize=(10,10/1.618),dpi=100)
plt.scatter(x,y,s=25,color=(0.6,0.6,0.3,0.7),marker='X')
plt.plot(x,yh)
plt.legend(['Ajuste polinomial','Datos'])
plt.title('Potencia contra Temperatura')
plt.xlabel('T (K)')
plt.ylabel('P (W)')
plt.legend(['Ajuste polinomial','Datos'])
plt.style.use('seaborn-whitegrid')
plt.show()


print(C,K,A,B)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-97906d6b3ee2> in <module>
#       3 #########################################
#       4 h=lambda x,C,K,A,B: C*((x**A)-(284.3176636**A))+K*((x-284.3176636)**B)
# ----> 5 popth,pcovh=cfit(h,x,y)
#       6 C,K,A,B=popth
#       7 yh=h(x,C,K,A,B)
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     787         cost = np.sum(infodict['fvec'] ** 2)
#     788         if ier not in [1, 2, 3, 4]:
# --> 789             raise RuntimeError("Optimal parameters not found: " + errmsg)
#     790     else:
#     791         # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
